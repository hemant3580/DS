# %%
import pandas as pd
# Out:
# C:\Users\bhase\anaconda3\lib\site-packages\mkl\__init__.py:54: RuntimeWarning: coroutine 'main' was never awaited
#   from ._py_mkl_service import *
# ...
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
df = pd.read_csv("C:/Users/bhase/Downloads/DS Practicals/HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.fillna(value = {'CRIM' :df['CRIM'].mean(), 'ZN' : df ['ZN'].mean(), 'INDUS' : df ['INDUS'].mean(),'CHAS' : df ['CHAS'].mean(), 'AGE' : df ['AGE'].mean(), 'LSTAT' : df ['LSTAT'].mean()}, inplace = True )

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
figure,  axes = plt.subplots(2, 3, figsize = (20,10))
sns.boxplot(ax = axes[0,0], data =df, x = 'CRIM')
sns.boxplot(ax = axes[0,1], data =df, x = 'MEDV')
# Out:
# <AxesSubplot:xlabel='MEDV'>

# %%
figure,axes = plt.subplots(5,3,figsize = (15,15))
sns.scatterplot(ax =axes[0,0],data = df, x ='CRIM',y = 'MEDV' )
sns.scatterplot(ax =axes[0,1],data = df, x ='ZN',y = 'MEDV' )
sns.scatterplot(ax =axes[0,2],data = df, x ='INDUS',y = 'MEDV' )
sns.scatterplot(ax =axes[1,0],data = df, x ='CHAS',y = 'MEDV' )
sns.scatterplot(ax =axes[1,1],data = df, x ='NOX',y = 'MEDV' )
sns.scatterplot(ax =axes[1,2],data = df, x ='RM',y = 'MEDV' )
sns.scatterplot(ax =axes[2,0],data = df, x ='AGE',y = 'MEDV' )
sns.scatterplot(ax =axes[2,1],data = df, x ='DIS',y = 'MEDV' )
sns.scatterplot(ax =axes[2,2],data = df, x ='RAD',y = 'MEDV' )
sns.scatterplot(ax =axes[3,0],data = df, x ='TAX',y = 'MEDV' )
sns.scatterplot(ax =axes[3,1],data = df, x ='PTRATIO',y = 'MEDV' )
sns.scatterplot(ax =axes[3,2],data = df, x ='B',y = 'MEDV' )
sns.scatterplot(ax =axes[4,0],data = df, x ='LSTAT',y = 'MEDV' )
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.182930  0.391161 -0.052223  0.410377 -0.215434  0.344934
# ZN      -0.182930  1.000000 -0.513336 -0.036147 -0.502287  0.316550 -0.541274
# INDUS    0.391161 -0.513336  1.000000  0.058035  0.740965 -0.381457  0.614592
# CHAS    -0.052223 -0.036147  0.058035  1.000000  0.073286  0.102284  0.075206
# NOX      0.410377 -0.502287  0.740965  0.073286  1.000000 -0.302188  0.711461
# RM      -0.215434  0.316550 -0.381457  0.102284 -0.302188  1.000000 -0.241351
# AGE      0.344934 -0.541274  0.614592  0.075206  0.711461 -0.241351  1.000000
# DIS     -0.366523  0.638388 -0.699639 -0.091680 -0.769230  0.205246 -0.724353
# RAD      0.608886 -0.306316  0.593176  0.001425  0.611441 -0.209847  0.449989
# TAX      0.566528 -0.308334  0.716062 -0.031483  0.668023 -0.292048  0.500589
# PTRATIO  0.273384 -0.403085  0.384806 -0.109310  0.188933 -0.355501  0.262723
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = df.loc[:,: 'LSTAT']
y = df['MEDV']

# %%
df1 = df.copy()

# %%
x = df1.loc[:,: 'LSTAT']
y = df1['MEDV']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state = 42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.7378739836922881

# %%
lr.score(x_test, y_test)
# Out:
# 0.6800331878713515

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df2 = df.copy()

# %%
x = df2.loc[:,:'LSTAT']
y = df2['MEDV']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.7378739836922881

# %%
lr.score(x_test, y_test)
# Out:
# 0.6800331878713515

# %%
#df.fillna(value =  {'xyz': df['XYZ'].mean()})
